# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
#it is a collection of command style functions that make matplotlib work like MATLAB and  create a figure, 
#create a plotting area in a figure, plot some lines in a plotting area, decorate the plot with labels, etc

# %%
print (pd.__version__)
# Out:
# 1.1.2

# %% [markdown]
# ###DATA FRAME

# %%
pd.DataFrame(data=[None],
             index=[None],
             columns=[None])
# Out:
#       NaN
# NaN  None

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
#you can see we created first DataFrame as a structure
#created a table marvel_data 
#Create a marvel_df pandas DataFrame with the given marvel data

marvel_df= pd.DataFrame(data=marvel_data)
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
#add new column to marvel_df
col_nam=['name','sex','first appearance']
marvel_df.columns=col_nam
marvel_df
# Out:
#                 name     sex  first appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %%
marvel_df
# Out:
#                               name     sex  first appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %%
#Drop 'Namor' and 'Hank Pym' rows

marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
marvel_df
# Out:
#                               name     sex  first appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# ...

# %%
# Show the first 5 elements on marvel_df

#marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor'], :] # bad!
marvel_df.loc['Spider-Man': 'Thor', :]
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
#marvel_df.iloc[:5,]
#marvel_df.head()
# Out:
#                             name   sex  first appearance
# name
# Spider-Man            Spider-Man  male              1962
# Captain America  Captain America  male              1941
# Wolverine              Wolverine  male              1974
# Iron Man                Iron Man  male              1963
# Thor                        Thor  male              1963

# %%
# Show the last 5 elements on marvel_df¶

#marvel_df.loc[['Hank Pym', 'Scarlet Witch', 'Wasp', 'Black Widow', 'Vision'], :] # bad!
#marvel_df.loc['Hank Pym':'Vision', :]
#marvel_df.iloc[-5:,]
#marvel_df.tail()
marvel_df.iloc[-5: ,]
# Out:
#                           name     sex  first appearance
# name
# Doctor Strange  Doctor Strange    male              1963
# Scarlet Witch    Scarlet Witch  female              1964
# Wasp                      Wasp  female              1963
# Black Widow        Black Widow  female              1964
# Vision                  Vision    male              1968

# %%
# Show just the sex of the first 5 elements on marvel_df¶

marvel_df.iloc[:5,].sex.to_frame()
#to_frame()Create a DataFrame with a column containing the Index.


#marvel_df.iloc[:5,]['sex'].to_frame()
#marvel_df.iloc[:5,].sex.to_frame()
#marvel_df.head().sex.to_frame()
# Out:
#                   sex
# name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %%
# Show the first_appearance of all middle elements on marvel_df
#marvel_df.iloc[[0, -1],][['sex', 'first_appearance']]
marvel_df.iloc[[0, -1],]
# Out:
#                   name   sex  first appearance
# name
# Spider-Man  Spider-Man  male              1962
# Vision          Vision  male              1968

# %%
#assigning value
marvel_df.loc['Vision', 'first appearance'] = 1964

marvel_df
# Out:
#                               name     sex  first appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# ...

# %%
marvel_df.index
# Out:
# Index(['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor',
#        'Thing', 'Mister Fantastic', 'Hulk', 'Beast', 'Invisible Woman',
#        'Storm', 'Hawkeye', 'Daredevil', 'Doctor Strange', 'Scarlet Witch',
#        'Wasp', 'Black Widow', 'Vision'],
#       dtype='object', name='name')

# %%
#Add a new column to marvel_df called 'years_since' with the years since first_appearance¶
marvel_df['years_since'] = 2018 - marvel_df['first appearance']

marvel_df
# Out:
#                               name     sex  first appearance  years_since
# name
# Spider-Man              Spider-Man    male              1962           56
# Captain America    Captain America    male              1941           77
# Wolverine                Wolverine    male              1974           44
# Iron Man                  Iron Man    male              1963           55
# Thor                          Thor    male              1963           55
# Thing                        Thing    male              1961           57
# Mister Fantastic  Mister Fantastic    male              1961           57
# Hulk                          Hulk    male              1962           56
# Beast                        Beast    male              1963           55
# Invisible Woman    Invisible Woman  female              1961           57
# Storm                        Storm  female              1975           43
# Hawkeye                    Hawkeye    male              1964           54
# ...

# %%
# Drop the name column as it's now the index¶

marvel_df = marvel_df.drop(['name'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-878d24bff20f> in <module>
#       1 # Drop the name column as it's now the index¶
#       2
# ----> 3 marvel_df = marvel_df.drop(['name'],axis=1)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4160                 weight  1.0     0.8
#    4161         """
# -> 4162         return super().drop(
#    4163             labels=labels,
#    4164             axis=axis,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3882         for axis, labels in axes.items():
#    3883             if labels is not None:
# ...

# %%
marvel_df
# Out:
#                      sex  first appearance  years_since
# name
# Spider-Man          male              1962           56
# Captain America     male              1941           77
# Wolverine           male              1974           44
# Iron Man            male              1963           55
# Thor                male              1963           55
# Thing               male              1961           57
# Mister Fantastic    male              1961           57
# Hulk                male              1962           56
# Beast               male              1963           55
# Invisible Woman   female              1961           57
# Storm             female              1975           43
# Hawkeye             male              1964           54
# Daredevil           male              1964           54
# Doctor Strange      male              1963           55
# Scarlet Witch     female              1964           54
# Wasp              female              1963           55
# ...

# %%
#DataFrame boolean arrays (also called masks)¶


mask = marvel_df['sex'] == 'female'

mask
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %%
#Given the marvel_df pandas DataFrame, get the male characters¶

mask =marvel_df['sex']=='male'
marvel_df[mask]
# Out:
#                    sex  first appearance  years_since
# name
# Spider-Man        male              1962           56
# Captain America   male              1941           77
# Wolverine         male              1974           44
# Iron Man          male              1963           55
# Thor              male              1963           55
# Thing             male              1961           57
# Mister Fantastic  male              1961           57
# Hulk              male              1962           56
# Beast             male              1963           55
# Hawkeye           male              1964           54
# Daredevil         male              1964           54
# Doctor Strange    male              1963           55
# Vision            male              1964           54

# %%
mask = marvel_df['first appearance'] > 1970
marvel_df[mask]
# Out:
#               sex  first appearance  years_since
# name
# Wolverine    male              1974           44
# Storm      female              1975           43

# %%
marvel_df.describe()
# Out:
#        first appearance  years_since
# count         18.000000    18.000000
# mean        1962.888889    55.111111
# std            6.720372     6.720372
# min         1941.000000    43.000000
# 25%         1962.000000    54.000000
# 50%         1963.000000    55.000000
# 75%         1964.000000    56.000000
# max         1975.000000    77.000000

# %%
marvel_df.years_since.mean()
# Out:
# 55.111111111111114

# %%
marvel_df.years_since.min()
# Out:
# 43

# %%
#Given the marvel_df pandas DataFrame, get the characters with the min value of first_appearance¶

mask = marvel_df['years_since'] == marvel_df.years_since.min()
marvel_df[mask]
# Out:
#           sex  first appearance  years_since
# name
# Storm  female              1975           43

# %%
mask = marvel_df['years_since'] >= marvel_df.years_since.max()
mask
# Out:
# name
# Spider-Man          False
# Captain America      True
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman     False
# Storm               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision              False
# Name: years_since, dtype: bool

# %%
#Reset index names of marvel_df¶

marvel_df = marvel_df.reset_index()

marvel_df
# Out:
#                 name     sex  first appearance  years_since
# 0         Spider-Man    male              1962           56
# 1    Captain America    male              1941           77
# 2          Wolverine    male              1974           44
# 3           Iron Man    male              1963           55
# 4               Thor    male              1963           55
# 5              Thing    male              1961           57
# 6   Mister Fantastic    male              1961           57
# 7               Hulk    male              1962           56
# 8              Beast    male              1963           55
# 9    Invisible Woman  female              1961           57
# 10             Storm  female              1975           43
# 11           Hawkeye    male              1964           54
# 12         Daredevil    male              1964           54
# 13    Doctor Strange    male              1963           55
# 14     Scarlet Witch  female              1964           54
# ...

# %%
# Plot the values of first_appearance¶
marvel_df.years_since.plot()
# Out:
# <AxesSubplot:>

# %%
#histogram
plt.hist(marvel_df.years_since)
# Out:
# (array([ 2.,  0.,  0., 12.,  3.,  0.,  0.,  0.,  0.,  1.]),
#  array([43. , 46.4, 49.8, 53.2, 56.6, 60. , 63.4, 66.8, 70.2, 73.6, 77. ]),
#  <BarContainer object of 10 artists>)
